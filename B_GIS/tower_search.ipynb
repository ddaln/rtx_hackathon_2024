# %%
import pandas as pd
import json
pd.set_option('display.max_rows', 50)

# %%
# Read the CSV file
csv_file_path = 'data/map_data/Existing_Commercial_Wireless_Telecommunication_Services_Facilities_in_San_Francisco_20240712.csv'
df = pd.read_csv(csv_file_path)

# Read the JSON file
json_file_path = 'data/call_data/tower_ping_logs.jsonl'
with open(json_file_path, 'r') as f:
    data_dict = json.load(f)

# Initialize an empty DataFrame to store the combined results
combined_df = pd.DataFrame()

# Iterate through each ping in the JSON data
for id, ping in enumerate(data_dict):
    data = data_dict[id]
    carrier = data["Carrier"]
    type_of_building = data["Type of Building"]
    type_of_services = data["Type of Consumer Services"]
    num_antennas = data["Number of Antennas"]
    rf_range = data["Radio Frequency Range (Megahertz)"]

    # Filter the CSV based on the ping data
    filtered_df = df[
    (df['Carrier'] == carrier) &
    (df['Type of Building'] == type_of_building) &
    (df['Type of Consumer Services'].str.contains(type_of_services)) &
    (df['Number of Antennas'].str.contains(str(num_antennas))) &
    (df['Radio Frequency Range (Megahertz)'].str.contains(rf_range))
]

    # Append the filtered data to the combined DataFrame
    combined_df = pd.concat([combined_df, filtered_df], ignore_index=True)

# Remove duplicates from the combined DataFrame
combined_df.drop_duplicates(inplace=True)

selected_columns = [
    'Carrier',
    'Type of Building',
    'Type of Consumer Services',
    'Number of Antennas',
    'Radio Frequency Range (Megahertz)',
    'Latitude',
    'Longitude'
]

call_location_df = combined_df[selected_columns]

call_location_df
# Out:
#      Carrier Type of Building Type of Consumer Services Number of Antennas
# 0    Tmobile     Utility Pole        voice, video, data                  1  \
# 1    Tmobile     Utility Pole        voice, video, data                  1
# 2    Tmobile     Utility Pole        voice, video, data                  1
# 3    Tmobile     Utility Pole        voice, video, data                  1
# 4    Tmobile     Utility Pole        voice, video, data                  1
# ..       ...              ...                       ...                ...
# 302     AT&T          Utility       voice, video & data                  1
# 303     AT&T          Utility       voice, video & data                  1
# 304     AT&T          Utility       voice, video & data                  1
# 305     AT&T          Utility       voice, video & data                  1
# 306     AT&T          Utility       voice, video & data                  1
#
#     Radio Frequency Range (Megahertz)   Latitude   Longitude
# 0                         1900 / 2100  37.777024 -122.508037
# 1                         1900 / 2100  37.749500 -122.508000
# 2                         1900 / 2100  37.778500 -122.497000
# 3                         1900 / 2100  37.760233 -122.504958
# 4                         1900 / 2100  37.753500 -122.425000
# ..                                ...        ...         ...
# 302                        1900, 5000  37.773360 -122.446140
# 303                 1900, 5000, 39000  37.790220 -122.393030
# 304                        1900, 5000  37.773240 -122.391550
# 305                        1900, 5000  37.748159 -122.418086
# 306                        1900, 5000  37.761080 -122.441110
#
# [259 rows x 7 columns]

# %%
# Filter rows based on your criteria
filtered_df = df[
    (df['Carrier'] == 'Tmobile') &
    (df['Type of Building'] == 'Utility Pole') &
    (df['Type of Consumer Services'].str.contains('voice, video, data')) &
    (df['Number of Antennas'].str.contains('1')) &
    (df['Radio Frequency Range (Megahertz)'].str.contains('1900 / 2100'))
]

selected_columns = [
    'Carrier',
    'Type of Building',
    'Type of Consumer Services',
    'Number of Antennas',
    'Radio Frequency Range (Megahertz)',
    'Latitude',
    'Longitude'
]

call_location_df = filtered_df[selected_columns]

call_location_df
# Out:
#      Carrier Type of Building Type of Consumer Services Number of Antennas
# 433  Tmobile     Utility Pole        voice, video, data                  1  \
# 440  Tmobile     Utility Pole        voice, video, data                  1
# 442  Tmobile     Utility Pole        voice, video, data                  1
# 446  Tmobile     Utility Pole        voice, video, data                  1
# 450  Tmobile     Utility Pole        voice, video, data                  1
# 466  Tmobile     Utility Pole        voice, video, data                  1
# 470  Tmobile     Utility Pole        voice, video, data                  1
# 471  Tmobile     Utility Pole        voice, video, data                  1
# 481  Tmobile     Utility Pole        voice, video, data                  1
# 483  Tmobile     Utility Pole        voice, video, data                  1
# 486  Tmobile     Utility Pole        voice, video, data                  1
# 490  Tmobile     Utility Pole        voice, video, data                  1
# 492  Tmobile     Utility Pole        voice, video, data                  1
# 493  Tmobile     Utility Pole        voice, video, data                  1
# 496  Tmobile     Utility Pole        voice, video, data                  1
# 500  Tmobile     Utility Pole        voice, video, data                  1
# 503  Tmobile     Utility Pole        voice, video, data                  1
# 508  Tmobile     Utility Pole        voice, video, data                  1
# 518  Tmobile     Utility Pole        voice, video, data                  1
# 520  Tmobile     Utility Pole        voice, video, data                  1
# 524  Tmobile     Utility Pole        voice, video, data                  1
# 536  Tmobile     Utility Pole        voice, video, data                  1
# 545  Tmobile     Utility Pole        voice, video, data                  1
# 546  Tmobile     Utility Pole        voice, video, data                  1
# 561  Tmobile     Utility Pole        voice, video, data                  1
# 563  Tmobile     Utility Pole        voice, video, data                  1
# 579  Tmobile     Utility Pole        voice, video, data                  1
# 580  Tmobile     Utility Pole        voice, video, data                  1
# 581  Tmobile     Utility Pole        voice, video, data                  1
# 585  Tmobile     Utility Pole        voice, video, data                  1
# 593  Tmobile     Utility Pole        voice, video, data                  1
# 611  Tmobile     Utility Pole        voice, video, data                  1
# 627  Tmobile     Utility Pole        voice, video, data                  1
# 631  Tmobile     Utility Pole        voice, video, data                  1
# 646  Tmobile     Utility Pole        voice, video, data                  1
# 664  Tmobile     Utility Pole        voice, video, data                  1
# 668  Tmobile     Utility Pole        voice, video, data                  1
# 678  Tmobile     Utility Pole        voice, video, data                  1
# 683  Tmobile     Utility Pole        voice, video, data                  1
# 693  Tmobile     Utility Pole        voice, video, data                  1
# 696  Tmobile     Utility Pole        voice, video, data                  1
# 702  Tmobile     Utility Pole        voice, video, data                  1
# 704  Tmobile     Utility Pole        voice, video, data                  1
# 712  Tmobile     Utility Pole        voice, video, data                  1
# 714  Tmobile     Utility Pole        voice, video, data                  1
# 721  Tmobile     Utility Pole        voice, video, data                  1
# 723  Tmobile     Utility Pole        voice, video, data                  1
# 742  Tmobile     Utility Pole        voice, video, data                  1
#
#     Radio Frequency Range (Megahertz)   Latitude   Longitude
# 433                       1900 / 2100  37.777024 -122.508037
# 440                       1900 / 2100  37.749500 -122.508000
# 442                       1900 / 2100  37.778500 -122.497000
# 446                       1900 / 2100  37.760233 -122.504958
# 450                       1900 / 2100  37.753500 -122.425000
# 466                       1900 / 2100  37.774500 -122.458000
# 470                       1900 / 2100  37.755000 -122.411000
# 471                       1900 / 2100  37.735900 -122.471000
# 481                       1900 / 2100  37.735100 -122.506000
# 483                       1900 / 2100  37.749919 -122.487861
# 486                       1900 / 2100  37.766265 -122.438579
# 490                       1900 / 2100  37.757800 -122.490000
# 492                       1900 / 2100  37.741700 -122.496000
# 493                       1900 / 2100  37.742239 -122.499222
# 496                       1900 / 2100  37.765100 -122.484000
# 500                       1900 / 2100  37.773100 -122.478000
# 503                       1900 / 2100  37.745432 -122.504993
# 508                       1900 / 2100  37.757508 -122.485645
# 518                       1900 / 2100  37.753600 -122.484000
# 520                       1900 / 2100  37.758600 -122.400000
# 524                       1900 / 2100  37.753992 -122.476558
# 536                       1900 / 2100  37.755749 -122.487260
# 545                       1900 / 2100  37.744400 -122.427000
# 546                       1900 / 2100  37.756597 -122.506903
# 561                       1900 / 2100  37.745300 -122.432000
# 563                       1900 / 2100  37.758800 -122.500000
# 579                       1900 / 2100  37.762400 -122.471000
# 580                       1900 / 2100  37.761600 -122.447000
# 581                       1900 / 2100  37.763900 -122.468000
# 585                       1900 / 2100  37.794600 -122.411000
# 593                       1900 / 2100  37.779401 -122.459942
# 611                       1900 / 2100  37.719120 -122.408748
# 627                       1900 / 2100  37.774861 -122.465031
# 631                       1900 / 2100  37.776100 -122.493000
# 646                       1900 / 2100  37.723600 -122.416000
# 664                       1900 / 2100  37.747600 -122.465000
# 668                       1900 / 2100  37.799600 -122.409000
# 678                       1900 / 2100  37.735500 -122.418000
# 683                       1900 / 2100  37.722300 -122.427850
# 693                       1900 / 2100  37.729500 -122.407000
# 696                       1900 / 2100  37.753600 -122.484000
# 702                       1900 / 2100  37.725000 -122.435000
# 704                       1900 / 2100  37.742200 -122.433000
# 712                       1900 / 2100  37.786000 -122.482000
# 714                       1900 / 2100  37.738492 -122.433964
# 721                       1900 / 2100  37.727170 -122.503502
# 723                       1900 / 2100  37.746900 -122.411000
# 742                       1900 / 2100  37.762307 -122.422466
